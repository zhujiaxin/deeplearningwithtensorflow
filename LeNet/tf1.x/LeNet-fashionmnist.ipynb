# %%
import tensorflow.compat.v1 as tf
import numpy as np
import utils.read_mnist as read_mnist
import time
import lenet

# %% [markdown]
# 把数据读取出来并返回
# 这里提供两个函数
# 分别是read_mnist和read_fashion_mnist

# %%
print(read_mnist.read_fashion_mnist.__doc__)
# Out:
# 返回fashion_mnist数据，两个参数分别是one_hot和standard来控制是否将数据归一化和变成OneHot
#         分别返回训练数据，训练标签，测试数据，测试标签，按照标签获得名字的一个字典

# %%
train_x, train_y, test_x, test_y ,index2word= read_mnist.read_fashion_mnist(one_hot=True, standard=True)
index_train = np.random.permutation(train_x.shape[0])
train_x, train_y = train_x[index_train], train_y[index_train]

# %%
print('训练数据有{}个,维度为{}行，{}列'.format(train_x.shape[0],train_x.shape[1],train_x.shape[2]))
print('测试数据有{}个,维度为{}行，{}列'.format(test_x.shape[0],test_x.shape[1],test_x.shape[2]))
# Out:
# 训练数据有10000个,维度为28行，28列
# 测试数据有60000个,维度为28行，28列

# %%
gpu_options = tf.GPUOptions(allow_growth=True)     #允许动态申请显存
tf.GPUOptions(per_process_gpu_memory_fraction=0.4) # 限制GPU显存使用率是40%
# Out:
# per_process_gpu_memory_fraction: 0.4

# %%
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
model = lenet.LeNet(lr_rate=0.01, regular=0.0000)
sess.run(tf.global_variables_initializer())

# %%
epochs = 500
batch_size = 64
saver = tf.train.Saver()
lr_rate = 0.01
for epoch in range(epochs):
    start = time.time()
    batch_sofar = 0
    for j in range(train_x.shape[0] // batch_size + 1):
        model.train(train_x=train_x[batch_sofar:batch_sofar + batch_size, :, :, :],
                    train_y=train_y[batch_sofar:batch_sofar + batch_size, :],
                    session=sess)
        batch_sofar += batch_size
        if batch_sofar > train_x.shape[0]:
            model.train(train_x=train_x[batch_sofar - batch_size:, :, :, :],
                        train_y=train_y[batch_sofar - batch_size:, :],
                        session=sess)
    if (epoch + 1) / 50 == 0:
        lr_rate = lr_rate / 2
        model.change_lr_rate(lr_rate)
    #rs = sess.run(merge, feed_dict={model.input_x: test_x, model.input_y: test_y})
    #file_writer.add_summary(rs, epoch)
    print('{:.0f} epoch use {:.2f} ms'.format(epoch, (time.time()-start)*1000))
    print('{:.0f} epoch loss on test data is {:.2f} '.format(epoch, model.compute_loss(test_x, test_y, session=sess)))
    print('{:.0f} epoch accuary on test data is {:.2f}% '.format(epoch, model.compute_accuracy(test_x, test_y, session=sess)*100))
    print('{:.0f} epoch accuary on train data is {:.2f}% '.format(epoch, model.compute_accuracy(train_x, train_y, session=sess)*100))
saver.save(sess, r'ckpt/lenet-ckpt', global_step=epoch)
# Out:
# 0 epoch use 2170.97 ms
# 0 epoch loss on test data is 2.28
# 0 epoch accuary on test data is 15.04%
# 0 epoch accuary on test data is 14.87%
# 1 epoch use 507.96 ms
# 1 epoch loss on test data is 2.24
# 1 epoch accuary on test data is 18.73%
# 1 epoch accuary on test data is 19.24%
# 2 epoch use 495.05 ms
# 2 epoch loss on test data is 2.09
# 2 epoch accuary on test data is 23.75%
# 2 epoch accuary on test data is 23.17%
# 3 epoch use 499.96 ms
# 3 epoch loss on test data is 1.70
# 3 epoch accuary on test data is 35.26%
# 3 epoch accuary on test data is 35.48%
# 4 epoch use 504.00 ms
# 4 epoch loss on test data is 1.43
# 4 epoch accuary on test data is 45.11%
# 4 epoch accuary on test data is 44.79%
# 5 epoch use 489.96 ms
# 5 epoch loss on test data is 1.28
# 5 epoch accuary on test data is 51.20%
# 5 epoch accuary on test data is 50.73%
# 6 epoch use 505.00 ms
# 6 epoch loss on test data is 1.16
# 6 epoch accuary on test data is 56.40%
# 6 epoch accuary on test data is 56.40%
# 7 epoch use 472.00 ms
# 7 epoch loss on test data is 1.07
# 7 epoch accuary on test data is 59.84%
# 7 epoch accuary on test data is 58.83%
# 8 epoch use 487.99 ms
# 8 epoch loss on test data is 1.01
# 8 epoch accuary on test data is 61.93%
# 8 epoch accuary on test data is 61.31%
# 9 epoch use 492.01 ms
# 9 epoch loss on test data is 0.97
# 9 epoch accuary on test data is 64.20%
# 9 epoch accuary on test data is 64.03%
# 10 epoch use 500.97 ms
# 10 epoch loss on test data is 0.92
# 10 epoch accuary on test data is 65.46%
# 10 epoch accuary on test data is 64.73%
# 11 epoch use 479.00 ms
# 11 epoch loss on test data is 0.90
# 11 epoch accuary on test data is 66.34%
# 11 epoch accuary on test data is 65.62%
# 12 epoch use 515.01 ms
# 12 epoch loss on test data is 0.87
# 12 epoch accuary on test data is 67.29%
# 12 epoch accuary on test data is 66.87%
# 13 epoch use 499.01 ms
# 13 epoch loss on test data is 0.85
# 13 epoch accuary on test data is 67.66%
# 13 epoch accuary on test data is 67.41%
# 14 epoch use 514.01 ms
# 14 epoch loss on test data is 0.84
# 14 epoch accuary on test data is 68.23%
# 14 epoch accuary on test data is 67.08%
# 15 epoch use 513.00 ms
# 15 epoch loss on test data is 0.82
# 15 epoch accuary on test data is 68.54%
# 15 epoch accuary on test data is 68.01%
# 16 epoch use 520.00 ms
# 16 epoch loss on test data is 0.80
# 16 epoch accuary on test data is 69.75%
# 16 epoch accuary on test data is 69.52%
# 17 epoch use 494.97 ms
# 17 epoch loss on test data is 0.80
# 17 epoch accuary on test data is 69.46%
# 17 epoch accuary on test data is 68.54%
# 18 epoch use 518.03 ms
# 18 epoch loss on test data is 0.79
# 18 epoch accuary on test data is 70.31%
# 18 epoch accuary on test data is 70.02%
# 19 epoch use 507.97 ms
# 19 epoch loss on test data is 0.77
# 19 epoch accuary on test data is 71.25%
# 19 epoch accuary on test data is 70.44%
# 20 epoch use 515.00 ms
# 20 epoch loss on test data is 0.76
# 20 epoch accuary on test data is 71.17%
# 20 epoch accuary on test data is 70.80%
# 21 epoch use 504.03 ms
# 21 epoch loss on test data is 0.75
# 21 epoch accuary on test data is 71.95%
# 21 epoch accuary on test data is 71.04%
# 22 epoch use 492.00 ms
# 22 epoch loss on test data is 0.75
# 22 epoch accuary on test data is 71.65%
# 22 epoch accuary on test data is 71.82%
# 23 epoch use 507.98 ms
# 23 epoch loss on test data is 0.74
# 23 epoch accuary on test data is 72.10%
# 23 epoch accuary on test data is 72.16%
# 24 epoch use 502.98 ms
# 24 epoch loss on test data is 0.73
# 24 epoch accuary on test data is 72.54%
# 24 epoch accuary on test data is 72.25%
# 25 epoch use 513.02 ms
# 25 epoch loss on test data is 0.74
# 25 epoch accuary on test data is 72.37%
# 25 epoch accuary on test data is 71.88%
# 26 epoch use 498.03 ms
# 26 epoch loss on test data is 0.71
# 26 epoch accuary on test data is 73.13%
# 26 epoch accuary on test data is 72.92%
# 27 epoch use 504.01 ms
# 27 epoch loss on test data is 0.70
# 27 epoch accuary on test data is 73.60%
# 27 epoch accuary on test data is 73.14%
# 28 epoch use 517.01 ms
# 28 epoch loss on test data is 0.70
# 28 epoch accuary on test data is 73.71%
# 28 epoch accuary on test data is 73.52%
# 29 epoch use 471.00 ms
# 29 epoch loss on test data is 0.71
# 29 epoch accuary on test data is 73.34%
# 29 epoch accuary on test data is 73.75%
# 30 epoch use 492.01 ms
# 30 epoch loss on test data is 0.70
# 30 epoch accuary on test data is 73.48%
# 30 epoch accuary on test data is 73.12%
# 31 epoch use 498.01 ms
# 31 epoch loss on test data is 0.68
# 31 epoch accuary on test data is 74.30%
# 31 epoch accuary on test data is 74.25%
# 32 epoch use 486.96 ms
# 32 epoch loss on test data is 0.68
# 32 epoch accuary on test data is 74.38%
# 32 epoch accuary on test data is 74.27%
# 33 epoch use 485.00 ms
# 33 epoch loss on test data is 0.68
# 33 epoch accuary on test data is 74.57%
# 33 epoch accuary on test data is 74.83%
# 34 epoch use 517.01 ms
# 34 epoch loss on test data is 0.67
# 34 epoch accuary on test data is 74.86%
# 34 epoch accuary on test data is 74.65%
# 35 epoch use 510.04 ms
# 35 epoch loss on test data is 0.67
# 35 epoch accuary on test data is 74.84%
# 35 epoch accuary on test data is 74.69%
# 36 epoch use 478.01 ms
# 36 epoch loss on test data is 0.67
# 36 epoch accuary on test data is 75.07%
# 36 epoch accuary on test data is 75.60%
# 37 epoch use 509.00 ms
# 37 epoch loss on test data is 0.65
# 37 epoch accuary on test data is 75.58%
# 37 epoch accuary on test data is 75.53%
# 38 epoch use 497.03 ms
# 38 epoch loss on test data is 0.65
# 38 epoch accuary on test data is 75.66%
# 38 epoch accuary on test data is 75.21%
# 39 epoch use 510.04 ms
# 39 epoch loss on test data is 0.66
# 39 epoch accuary on test data is 75.70%
# 39 epoch accuary on test data is 75.79%
# 40 epoch use 502.96 ms
# 40 epoch loss on test data is 0.66
# 40 epoch accuary on test data is 75.27%
# 40 epoch accuary on test data is 74.78%
# 41 epoch use 478.98 ms
# 41 epoch loss on test data is 0.65
# 41 epoch accuary on test data is 75.33%
# 41 epoch accuary on test data is 74.99%
# 42 epoch use 508.99 ms
# 42 epoch loss on test data is 0.64
# 42 epoch accuary on test data is 76.03%
# 42 epoch accuary on test data is 76.33%
# 43 epoch use 506.99 ms
# 43 epoch loss on test data is 0.65
# 43 epoch accuary on test data is 75.73%
# 43 epoch accuary on test data is 75.47%
# 44 epoch use 501.96 ms
# 44 epoch loss on test data is 0.64
# 44 epoch accuary on test data is 76.35%
# 44 epoch accuary on test data is 76.25%
# 45 epoch use 485.99 ms
# 45 epoch loss on test data is 0.63
# 45 epoch accuary on test data is 76.39%
# 45 epoch accuary on test data is 76.69%
# 46 epoch use 482.98 ms
# 46 epoch loss on test data is 0.63
# 46 epoch accuary on test data is 76.87%
# 46 epoch accuary on test data is 76.61%
# 47 epoch use 510.96 ms
# 47 epoch loss on test data is 0.63
# 47 epoch accuary on test data is 76.55%
# 47 epoch accuary on test data is 76.57%
# 48 epoch use 472.00 ms
# 48 epoch loss on test data is 0.63
# 48 epoch accuary on test data is 76.72%
# 48 epoch accuary on test data is 76.75%
# 49 epoch use 489.01 ms
# 49 epoch loss on test data is 0.63
# 49 epoch accuary on test data is 76.88%
# 49 epoch accuary on test data is 76.85%
# 50 epoch use 487.96 ms
# 50 epoch loss on test data is 0.62
# 50 epoch accuary on test data is 77.09%
# 50 epoch accuary on test data is 77.43%
# 51 epoch use 522.01 ms
# 51 epoch loss on test data is 0.63
# 51 epoch accuary on test data is 76.70%
# 51 epoch accuary on test data is 77.21%
# 52 epoch use 476.96 ms
# 52 epoch loss on test data is 0.61
# 52 epoch accuary on test data is 77.44%
# 52 epoch accuary on test data is 77.49%
# 53 epoch use 482.01 ms
# 53 epoch loss on test data is 0.62
# 53 epoch accuary on test data is 77.12%
# 53 epoch accuary on test data is 77.03%
# 54 epoch use 501.96 ms
# 54 epoch loss on test data is 0.61
# 54 epoch accuary on test data is 77.57%
# 54 epoch accuary on test data is 77.62%
# 55 epoch use 498.99 ms
# 55 epoch loss on test data is 0.60
# 55 epoch accuary on test data is 78.01%
# 55 epoch accuary on test data is 78.49%
# 56 epoch use 507.00 ms
# 56 epoch loss on test data is 0.60
# 56 epoch accuary on test data is 78.00%
# 56 epoch accuary on test data is 78.31%
# 57 epoch use 505.02 ms
# 57 epoch loss on test data is 0.60
# 57 epoch accuary on test data is 78.14%
# 57 epoch accuary on test data is 78.58%
# 58 epoch use 489.00 ms
# 58 epoch loss on test data is 0.60
# 58 epoch accuary on test data is 78.16%
# 58 epoch accuary on test data is 78.11%
# 59 epoch use 509.99 ms
# 59 epoch loss on test data is 0.60
# 59 epoch accuary on test data is 78.21%
# 59 epoch accuary on test data is 78.63%
# 60 epoch use 502.99 ms
# 60 epoch loss on test data is 0.60
# 60 epoch accuary on test data is 78.21%
# 60 epoch accuary on test data is 79.22%
# 61 epoch use 499.02 ms
# 61 epoch loss on test data is 0.60
# 61 epoch accuary on test data is 78.41%
# 61 epoch accuary on test data is 79.30%
# 62 epoch use 485.98 ms
# 62 epoch loss on test data is 0.59
# 62 epoch accuary on test data is 78.48%
# 62 epoch accuary on test data is 79.03%
# 63 epoch use 504.00 ms
# 63 epoch loss on test data is 0.59
# 63 epoch accuary on test data is 78.88%
# 63 epoch accuary on test data is 79.15%
# 64 epoch use 518.00 ms
# 64 epoch loss on test data is 0.59
# 64 epoch accuary on test data is 78.37%
# 64 epoch accuary on test data is 78.37%
# 65 epoch use 489.99 ms
# 65 epoch loss on test data is 0.59
# 65 epoch accuary on test data is 78.70%
# 65 epoch accuary on test data is 79.49%
# 66 epoch use 501.00 ms
# 66 epoch loss on test data is 0.58
# 66 epoch accuary on test data is 78.89%
# 66 epoch accuary on test data is 79.30%
# 67 epoch use 496.96 ms
# 67 epoch loss on test data is 0.58
# 67 epoch accuary on test data is 79.09%
# 67 epoch accuary on test data is 79.25%
# 68 epoch use 478.96 ms
# 68 epoch loss on test data is 0.58
# 68 epoch accuary on test data is 79.29%
# 68 epoch accuary on test data is 79.78%
# 69 epoch use 493.01 ms
# 69 epoch loss on test data is 0.58
# 69 epoch accuary on test data is 79.17%
# 69 epoch accuary on test data is 79.20%
# 70 epoch use 492.96 ms
# 70 epoch loss on test data is 0.58
# 70 epoch accuary on test data is 79.21%
# 70 epoch accuary on test data is 79.43%
# 71 epoch use 504.00 ms
# 71 epoch loss on test data is 0.58
# 71 epoch accuary on test data is 79.29%
# 71 epoch accuary on test data is 79.58%
# 72 epoch use 509.03 ms
# 72 epoch loss on test data is 0.58
# 72 epoch accuary on test data is 79.20%
# 72 epoch accuary on test data is 79.72%
# 73 epoch use 484.01 ms
# 73 epoch loss on test data is 0.58
# 73 epoch accuary on test data is 79.44%
# 73 epoch accuary on test data is 79.91%
# 74 epoch use 502.01 ms
# 74 epoch loss on test data is 0.57
# 74 epoch accuary on test data is 79.41%
# 74 epoch accuary on test data is 79.99%
# 75 epoch use 501.00 ms
# 75 epoch loss on test data is 0.57
# 75 epoch accuary on test data is 79.61%
# 75 epoch accuary on test data is 80.07%
# 76 epoch use 510.98 ms
# 76 epoch loss on test data is 0.57
# 76 epoch accuary on test data is 79.64%
# 76 epoch accuary on test data is 80.05%
# 77 epoch use 505.97 ms
# 77 epoch loss on test data is 0.56
# 77 epoch accuary on test data is 79.94%
# 77 epoch accuary on test data is 79.88%
# 78 epoch use 500.96 ms
# 78 epoch loss on test data is 0.57
# 78 epoch accuary on test data is 79.71%
# 78 epoch accuary on test data is 80.29%
# 79 epoch use 546.03 ms
# 79 epoch loss on test data is 0.57
# 79 epoch accuary on test data is 79.83%
# 79 epoch accuary on test data is 80.47%
# 80 epoch use 467.01 ms
# 80 epoch loss on test data is 0.56
# 80 epoch accuary on test data is 79.85%
# 80 epoch accuary on test data is 80.46%
# 81 epoch use 513.00 ms
# 81 epoch loss on test data is 0.57
# 81 epoch accuary on test data is 79.96%
# 81 epoch accuary on test data is 80.43%
# 82 epoch use 492.00 ms
# 82 epoch loss on test data is 0.56
# 82 epoch accuary on test data is 80.17%
# 82 epoch accuary on test data is 80.90%
# 83 epoch use 499.00 ms
# 83 epoch loss on test data is 0.55
# 83 epoch accuary on test data is 80.52%
# 83 epoch accuary on test data is 80.60%
# 84 epoch use 497.97 ms
# 84 epoch loss on test data is 0.55
# 84 epoch accuary on test data is 80.45%
# 84 epoch accuary on test data is 81.12%
# 85 epoch use 499.00 ms
# 85 epoch loss on test data is 0.56
# 85 epoch accuary on test data is 80.11%
# 85 epoch accuary on test data is 81.04%
# 86 epoch use 485.96 ms
# 86 epoch loss on test data is 0.55
# 86 epoch accuary on test data is 80.29%
# 86 epoch accuary on test data is 81.01%
# 87 epoch use 489.98 ms
# 87 epoch loss on test data is 0.55
# 87 epoch accuary on test data is 80.73%
# 87 epoch accuary on test data is 81.34%
# 88 epoch use 516.04 ms
# 88 epoch loss on test data is 0.55
# 88 epoch accuary on test data is 80.55%
# 88 epoch accuary on test data is 81.55%
# 89 epoch use 526.99 ms
# 89 epoch loss on test data is 0.56
# 89 epoch accuary on test data is 80.19%
# 89 epoch accuary on test data is 80.97%
# 90 epoch use 507.03 ms
# 90 epoch loss on test data is 0.55
# 90 epoch accuary on test data is 80.16%
# 90 epoch accuary on test data is 81.12%
# 91 epoch use 514.02 ms
# 91 epoch loss on test data is 0.55
# 91 epoch accuary on test data is 80.68%
# 91 epoch accuary on test data is 81.80%
# 92 epoch use 509.00 ms
# 92 epoch loss on test data is 0.55
# 92 epoch accuary on test data is 80.75%
# 92 epoch accuary on test data is 81.54%
# 93 epoch use 491.01 ms
# 93 epoch loss on test data is 0.54
# 93 epoch accuary on test data is 80.74%
# 93 epoch accuary on test data is 81.52%
# 94 epoch use 496.00 ms
# 94 epoch loss on test data is 0.54
# 94 epoch accuary on test data is 81.06%
# 94 epoch accuary on test data is 81.63%
# 95 epoch use 492.03 ms
# 95 epoch loss on test data is 0.54
# 95 epoch accuary on test data is 80.99%
# 95 epoch accuary on test data is 81.89%
# 96 epoch use 502.00 ms
# 96 epoch loss on test data is 0.53
# 96 epoch accuary on test data is 81.12%
# 96 epoch accuary on test data is 81.92%
# 97 epoch use 477.96 ms
# 97 epoch loss on test data is 0.55
# 97 epoch accuary on test data is 80.90%
# 97 epoch accuary on test data is 81.50%
# 98 epoch use 485.00 ms
# 98 epoch loss on test data is 0.54
# 98 epoch accuary on test data is 81.09%
# 98 epoch accuary on test data is 82.27%
# 99 epoch use 513.97 ms
# 99 epoch loss on test data is 0.53
# 99 epoch accuary on test data is 81.16%
# 99 epoch accuary on test data is 81.93%
# 100 epoch use 558.01 ms
# 100 epoch loss on test data is 0.53
# 100 epoch accuary on test data is 81.24%
# 100 epoch accuary on test data is 81.69%
# 101 epoch use 512.05 ms
# 101 epoch loss on test data is 0.53
# 101 epoch accuary on test data is 81.36%
# 101 epoch accuary on test data is 81.73%
# 102 epoch use 494.02 ms
# 102 epoch loss on test data is 0.53
# 102 epoch accuary on test data is 81.34%
# 102 epoch accuary on test data is 82.16%
# 103 epoch use 529.00 ms
# 103 epoch loss on test data is 0.53
# 103 epoch accuary on test data is 81.39%
# 103 epoch accuary on test data is 82.39%
# 104 epoch use 504.97 ms
# 104 epoch loss on test data is 0.53
# 104 epoch accuary on test data is 81.33%
# 104 epoch accuary on test data is 82.39%
# 105 epoch use 531.96 ms
# 105 epoch loss on test data is 0.53
# 105 epoch accuary on test data is 81.51%
# 105 epoch accuary on test data is 82.50%
# 106 epoch use 478.98 ms
# 106 epoch loss on test data is 0.53
# 106 epoch accuary on test data is 81.33%
# 106 epoch accuary on test data is 82.39%
# 107 epoch use 515.00 ms
# 107 epoch loss on test data is 0.52
# 107 epoch accuary on test data is 81.56%
# 107 epoch accuary on test data is 82.62%
# 108 epoch use 483.00 ms
# 108 epoch loss on test data is 0.52
# 108 epoch accuary on test data is 81.55%
# 108 epoch accuary on test data is 82.21%
# 109 epoch use 486.00 ms
# 109 epoch loss on test data is 0.53
# 109 epoch accuary on test data is 81.41%
# 109 epoch accuary on test data is 82.64%
# 110 epoch use 501.96 ms
# 110 epoch loss on test data is 0.52
# 110 epoch accuary on test data is 81.59%
# 110 epoch accuary on test data is 82.69%
# 111 epoch use 490.01 ms
# 111 epoch loss on test data is 0.53
# 111 epoch accuary on test data is 81.76%
# 111 epoch accuary on test data is 82.47%
# 112 epoch use 515.01 ms
# 112 epoch loss on test data is 0.53
# 112 epoch accuary on test data is 81.37%
# 112 epoch accuary on test data is 82.60%
# 113 epoch use 504.01 ms
# 113 epoch loss on test data is 0.53
# 113 epoch accuary on test data is 81.51%
# 113 epoch accuary on test data is 82.85%
# 114 epoch use 504.96 ms
# 114 epoch loss on test data is 0.52
# 114 epoch accuary on test data is 81.75%
# 114 epoch accuary on test data is 82.77%
# 115 epoch use 506.03 ms
# 115 epoch loss on test data is 0.52
# 115 epoch accuary on test data is 81.72%
# 115 epoch accuary on test data is 83.15%
# 116 epoch use 487.98 ms
# 116 epoch loss on test data is 0.52
# 116 epoch accuary on test data is 82.11%
# 116 epoch accuary on test data is 83.56%
# 117 epoch use 516.96 ms
# 117 epoch loss on test data is 0.52
# 117 epoch accuary on test data is 82.05%
# 117 epoch accuary on test data is 82.99%
# 118 epoch use 505.00 ms
# 118 epoch loss on test data is 0.52
# 118 epoch accuary on test data is 82.03%
# 118 epoch accuary on test data is 83.10%
# 119 epoch use 505.00 ms
# 119 epoch loss on test data is 0.51
# 119 epoch accuary on test data is 81.73%
# 119 epoch accuary on test data is 83.42%
# 120 epoch use 485.99 ms
# 120 epoch loss on test data is 0.52
# 120 epoch accuary on test data is 81.88%
# 120 epoch accuary on test data is 83.37%
# 121 epoch use 498.96 ms
# 121 epoch loss on test data is 0.52
# 121 epoch accuary on test data is 81.74%
# 121 epoch accuary on test data is 83.40%
# 122 epoch use 513.96 ms
# 122 epoch loss on test data is 0.52
# 122 epoch accuary on test data is 81.81%
# 122 epoch accuary on test data is 83.08%
# 123 epoch use 483.00 ms
# 123 epoch loss on test data is 0.51
# 123 epoch accuary on test data is 82.15%
# 123 epoch accuary on test data is 83.19%
# 124 epoch use 484.98 ms
# 124 epoch loss on test data is 0.51
# 124 epoch accuary on test data is 82.34%
# 124 epoch accuary on test data is 83.40%
# 125 epoch use 479.00 ms
# 125 epoch loss on test data is 0.51
# 125 epoch accuary on test data is 82.26%
# 125 epoch accuary on test data is 83.33%
# 126 epoch use 482.02 ms
# 126 epoch loss on test data is 0.51
# 126 epoch accuary on test data is 82.28%
# 126 epoch accuary on test data is 83.42%
# 127 epoch use 503.97 ms
# 127 epoch loss on test data is 0.52
# 127 epoch accuary on test data is 82.02%
# 127 epoch accuary on test data is 83.15%
# 128 epoch use 510.00 ms
# 128 epoch loss on test data is 0.51
# 128 epoch accuary on test data is 82.38%
# 128 epoch accuary on test data is 83.91%
# 129 epoch use 490.00 ms
# 129 epoch loss on test data is 0.51
# 129 epoch accuary on test data is 82.15%
# 129 epoch accuary on test data is 83.67%
# 130 epoch use 478.97 ms
# 130 epoch loss on test data is 0.50
# 130 epoch accuary on test data is 82.36%
# 130 epoch accuary on test data is 83.62%
# 131 epoch use 499.96 ms
# 131 epoch loss on test data is 0.50
# 131 epoch accuary on test data is 82.45%
# 131 epoch accuary on test data is 84.09%
# 132 epoch use 507.96 ms
# 132 epoch loss on test data is 0.50
# 132 epoch accuary on test data is 82.54%
# 132 epoch accuary on test data is 84.05%
# 133 epoch use 495.00 ms
# 133 epoch loss on test data is 0.51
# 133 epoch accuary on test data is 82.34%
# 133 epoch accuary on test data is 83.66%
# 134 epoch use 474.00 ms
# 134 epoch loss on test data is 0.50
# 134 epoch accuary on test data is 82.64%
# 134 epoch accuary on test data is 84.25%
# 135 epoch use 505.98 ms
# 135 epoch loss on test data is 0.50
# 135 epoch accuary on test data is 82.62%
# 135 epoch accuary on test data is 84.25%
# 136 epoch use 509.00 ms
# 136 epoch loss on test data is 0.51
# 136 epoch accuary on test data is 82.36%
# 136 epoch accuary on test data is 83.62%
# 137 epoch use 500.00 ms
# 137 epoch loss on test data is 0.51
# 137 epoch accuary on test data is 82.51%
# 137 epoch accuary on test data is 83.43%
# 138 epoch use 500.00 ms
# 138 epoch loss on test data is 0.50
# 138 epoch accuary on test data is 82.51%
# 138 epoch accuary on test data is 84.66%
# 139 epoch use 490.00 ms
# 139 epoch loss on test data is 0.51
# 139 epoch accuary on test data is 82.20%
# 139 epoch accuary on test data is 83.74%
# 140 epoch use 498.01 ms
# 140 epoch loss on test data is 0.49
# 140 epoch accuary on test data is 82.66%
# 140 epoch accuary on test data is 84.62%
# 141 epoch use 511.97 ms
# 141 epoch loss on test data is 0.51
# 141 epoch accuary on test data is 82.55%
# 141 epoch accuary on test data is 84.10%
# 142 epoch use 505.00 ms
# 142 epoch loss on test data is 0.51
# 142 epoch accuary on test data is 82.42%
# 142 epoch accuary on test data is 84.12%
# 143 epoch use 486.01 ms
# 143 epoch loss on test data is 0.50
# 143 epoch accuary on test data is 82.63%
# 143 epoch accuary on test data is 84.51%
# 144 epoch use 498.00 ms
# 144 epoch loss on test data is 0.50
# 144 epoch accuary on test data is 82.75%
# 144 epoch accuary on test data is 84.06%
# 145 epoch use 501.00 ms
# 145 epoch loss on test data is 0.50
# 145 epoch accuary on test data is 82.72%
# 145 epoch accuary on test data is 84.41%
# 146 epoch use 495.01 ms
# 146 epoch loss on test data is 0.50
# 146 epoch accuary on test data is 82.56%
# 146 epoch accuary on test data is 84.55%
# 147 epoch use 512.01 ms
# 147 epoch loss on test data is 0.49
# 147 epoch accuary on test data is 82.95%
# 147 epoch accuary on test data is 84.49%
# 148 epoch use 496.99 ms
# 148 epoch loss on test data is 0.49
# 148 epoch accuary on test data is 83.05%
# 148 epoch accuary on test data is 84.83%
# 149 epoch use 492.00 ms
# 149 epoch loss on test data is 0.49
# 149 epoch accuary on test data is 82.79%
# 149 epoch accuary on test data is 84.50%
# 150 epoch use 482.00 ms
# 150 epoch loss on test data is 0.49
# 150 epoch accuary on test data is 82.84%
# 150 epoch accuary on test data is 84.70%
# 151 epoch use 497.00 ms
# 151 epoch loss on test data is 0.50
# 151 epoch accuary on test data is 82.78%
# 151 epoch accuary on test data is 84.97%
# 152 epoch use 507.01 ms
# 152 epoch loss on test data is 0.50
# 152 epoch accuary on test data is 83.01%
# 152 epoch accuary on test data is 84.78%
# 153 epoch use 502.98 ms
# 153 epoch loss on test data is 0.49
# 153 epoch accuary on test data is 83.17%
# 153 epoch accuary on test data is 85.02%
# 154 epoch use 504.97 ms
# 154 epoch loss on test data is 0.49
# 154 epoch accuary on test data is 82.87%
# 154 epoch accuary on test data is 84.56%
# 155 epoch use 507.00 ms
# 155 epoch loss on test data is 0.49
# 155 epoch accuary on test data is 83.16%
# 155 epoch accuary on test data is 85.16%
# 156 epoch use 495.00 ms
# 156 epoch loss on test data is 0.49
# 156 epoch accuary on test data is 83.35%
# 156 epoch accuary on test data is 84.49%
# 157 epoch use 519.98 ms
# 157 epoch loss on test data is 0.49
# 157 epoch accuary on test data is 82.97%
# 157 epoch accuary on test data is 84.84%
# 158 epoch use 507.00 ms
# 158 epoch loss on test data is 0.49
# 158 epoch accuary on test data is 83.17%
# 158 epoch accuary on test data is 84.89%
# 159 epoch use 516.96 ms
# 159 epoch loss on test data is 0.49
# 159 epoch accuary on test data is 83.17%
# 159 epoch accuary on test data is 84.71%
# 160 epoch use 507.96 ms
# 160 epoch loss on test data is 0.49
# 160 epoch accuary on test data is 83.11%
# 160 epoch accuary on test data is 85.16%
# 161 epoch use 508.01 ms
# 161 epoch loss on test data is 0.49
# 161 epoch accuary on test data is 83.14%
# 161 epoch accuary on test data is 84.80%
# 162 epoch use 497.04 ms
# 162 epoch loss on test data is 0.49
# 162 epoch accuary on test data is 83.13%
# 162 epoch accuary on test data is 85.44%
# 163 epoch use 503.04 ms
# 163 epoch loss on test data is 0.49
# 163 epoch accuary on test data is 83.33%
# 163 epoch accuary on test data is 85.72%
# 164 epoch use 502.99 ms
# 164 epoch loss on test data is 0.49
# 164 epoch accuary on test data is 82.88%
# 164 epoch accuary on test data is 85.22%
# 165 epoch use 481.00 ms
# 165 epoch loss on test data is 0.49
# 165 epoch accuary on test data is 83.24%
# 165 epoch accuary on test data is 84.83%
# 166 epoch use 500.02 ms
# 166 epoch loss on test data is 0.49
# 166 epoch accuary on test data is 83.38%
# 166 epoch accuary on test data is 85.35%
# 167 epoch use 496.00 ms
# 167 epoch loss on test data is 0.48
# 167 epoch accuary on test data is 83.29%
# 167 epoch accuary on test data is 85.64%
# 168 epoch use 492.01 ms
# 168 epoch loss on test data is 0.49
# 168 epoch accuary on test data is 83.05%
# 168 epoch accuary on test data is 85.30%
# 169 epoch use 500.00 ms
# 169 epoch loss on test data is 0.49
# 169 epoch accuary on test data is 83.53%
# 169 epoch accuary on test data is 85.74%
# 170 epoch use 506.97 ms
# 170 epoch loss on test data is 0.49
# 170 epoch accuary on test data is 83.10%
# 170 epoch accuary on test data is 85.39%
# 171 epoch use 509.96 ms
# 171 epoch loss on test data is 0.48
# 171 epoch accuary on test data is 83.34%
# 171 epoch accuary on test data is 85.51%
# 172 epoch use 515.99 ms
# 172 epoch loss on test data is 0.49
# 172 epoch accuary on test data is 83.53%
# 172 epoch accuary on test data is 85.61%
# 173 epoch use 499.96 ms
# 173 epoch loss on test data is 0.49
# 173 epoch accuary on test data is 83.32%
# 173 epoch accuary on test data is 85.27%
# 174 epoch use 515.96 ms
# 174 epoch loss on test data is 0.48
# 174 epoch accuary on test data is 83.48%
# 174 epoch accuary on test data is 85.53%
# 175 epoch use 475.00 ms
# 175 epoch loss on test data is 0.48
# 175 epoch accuary on test data is 83.27%
# 175 epoch accuary on test data is 85.73%
# 176 epoch use 504.01 ms
# 176 epoch loss on test data is 0.48
# 176 epoch accuary on test data is 83.46%
# 176 epoch accuary on test data is 85.99%
# 177 epoch use 495.00 ms
# 177 epoch loss on test data is 0.48
# 177 epoch accuary on test data is 83.72%
# 177 epoch accuary on test data is 85.88%
# 178 epoch use 506.00 ms
# 178 epoch loss on test data is 0.49
# 178 epoch accuary on test data is 83.35%
# 178 epoch accuary on test data is 85.18%
# 179 epoch use 501.02 ms
# 179 epoch loss on test data is 0.48
# 179 epoch accuary on test data is 83.34%
# 179 epoch accuary on test data is 85.40%
# 180 epoch use 505.00 ms
# 180 epoch loss on test data is 0.48
# 180 epoch accuary on test data is 83.84%
# 180 epoch accuary on test data is 85.81%
# 181 epoch use 492.00 ms
# 181 epoch loss on test data is 0.48
# 181 epoch accuary on test data is 83.75%
# 181 epoch accuary on test data is 85.94%
# 182 epoch use 512.96 ms
# 182 epoch loss on test data is 0.50
# 182 epoch accuary on test data is 83.19%
# 182 epoch accuary on test data is 84.66%
# 183 epoch use 490.97 ms
# 183 epoch loss on test data is 0.48
# 183 epoch accuary on test data is 83.60%
# 183 epoch accuary on test data is 85.44%
# 184 epoch use 488.01 ms
# 184 epoch loss on test data is 0.48
# 184 epoch accuary on test data is 83.63%
# 184 epoch accuary on test data is 85.87%
# 185 epoch use 486.96 ms
# 185 epoch loss on test data is 0.47
# 185 epoch accuary on test data is 83.67%
# 185 epoch accuary on test data is 86.16%
# 186 epoch use 493.98 ms
# 186 epoch loss on test data is 0.48
# 186 epoch accuary on test data is 83.67%
# 186 epoch accuary on test data is 86.01%
# 187 epoch use 512.00 ms
# 187 epoch loss on test data is 0.48
# 187 epoch accuary on test data is 83.78%
# 187 epoch accuary on test data is 85.78%
# 188 epoch use 516.96 ms
# 188 epoch loss on test data is 0.48
# 188 epoch accuary on test data is 83.64%
# 188 epoch accuary on test data is 86.35%
# 189 epoch use 508.00 ms
# 189 epoch loss on test data is 0.48
# 189 epoch accuary on test data is 83.89%
# 189 epoch accuary on test data is 86.06%
# 190 epoch use 508.00 ms
# 190 epoch loss on test data is 0.48
# 190 epoch accuary on test data is 83.78%
# 190 epoch accuary on test data is 86.20%
# 191 epoch use 506.00 ms
# 191 epoch loss on test data is 0.48
# 191 epoch accuary on test data is 83.82%
# 191 epoch accuary on test data is 86.12%
# 192 epoch use 509.00 ms
# 192 epoch loss on test data is 0.48
# 192 epoch accuary on test data is 83.74%
# 192 epoch accuary on test data is 86.24%
# 193 epoch use 469.00 ms
# 193 epoch loss on test data is 0.48
# 193 epoch accuary on test data is 83.75%
# 193 epoch accuary on test data is 86.72%
# 194 epoch use 481.01 ms
# 194 epoch loss on test data is 0.48
# 194 epoch accuary on test data is 83.75%
# 194 epoch accuary on test data is 86.23%
# 195 epoch use 508.00 ms
# 195 epoch loss on test data is 0.47
# 195 epoch accuary on test data is 83.78%
# 195 epoch accuary on test data is 86.20%
# 196 epoch use 481.99 ms
# 196 epoch loss on test data is 0.48
# 196 epoch accuary on test data is 83.83%
# 196 epoch accuary on test data is 86.36%
# 197 epoch use 535.00 ms
# 197 epoch loss on test data is 0.48
# 197 epoch accuary on test data is 83.31%
# 197 epoch accuary on test data is 85.95%
# 198 epoch use 534.00 ms
# 198 epoch loss on test data is 0.47
# 198 epoch accuary on test data is 84.06%
# 198 epoch accuary on test data is 86.69%
# 199 epoch use 505.41 ms
# 199 epoch loss on test data is 0.49
# 199 epoch accuary on test data is 83.73%
# 199 epoch accuary on test data is 86.36%
# 200 epoch use 519.00 ms
# 200 epoch loss on test data is 0.48
# 200 epoch accuary on test data is 83.94%
# 200 epoch accuary on test data is 86.58%
# 201 epoch use 499.96 ms
# 201 epoch loss on test data is 0.47
# 201 epoch accuary on test data is 83.87%
# 201 epoch accuary on test data is 86.16%
# 202 epoch use 503.00 ms
# 202 epoch loss on test data is 0.48
# 202 epoch accuary on test data is 83.81%
# 202 epoch accuary on test data is 86.10%
# 203 epoch use 507.01 ms
# 203 epoch loss on test data is 0.48
# 203 epoch accuary on test data is 83.61%
# 203 epoch accuary on test data is 86.55%
# 204 epoch use 510.96 ms
# 204 epoch loss on test data is 0.48
# 204 epoch accuary on test data is 84.02%
# 204 epoch accuary on test data is 86.24%
# 205 epoch use 502.00 ms
# 205 epoch loss on test data is 0.48
# 205 epoch accuary on test data is 83.87%
# 205 epoch accuary on test data is 86.83%
# 206 epoch use 514.00 ms
# 206 epoch loss on test data is 0.47
# 206 epoch accuary on test data is 83.78%
# 206 epoch accuary on test data is 86.86%
# 207 epoch use 494.00 ms
# 207 epoch loss on test data is 0.48
# 207 epoch accuary on test data is 83.85%
# 207 epoch accuary on test data is 86.71%
# 208 epoch use 488.01 ms
# 208 epoch loss on test data is 0.47
# 208 epoch accuary on test data is 83.85%
# 208 epoch accuary on test data is 86.44%
# 209 epoch use 517.97 ms
# 209 epoch loss on test data is 0.48
# 209 epoch accuary on test data is 83.86%
# 209 epoch accuary on test data is 86.74%
# 210 epoch use 512.00 ms
# 210 epoch loss on test data is 0.48
# 210 epoch accuary on test data is 83.96%
# 210 epoch accuary on test data is 86.59%
# 211 epoch use 524.99 ms
# 211 epoch loss on test data is 0.47
# 211 epoch accuary on test data is 83.96%
# 211 epoch accuary on test data is 86.44%
# 212 epoch use 526.00 ms
# 212 epoch loss on test data is 0.47
# 212 epoch accuary on test data is 83.99%
# 212 epoch accuary on test data is 86.62%
# 213 epoch use 528.00 ms
# 213 epoch loss on test data is 0.48
# 213 epoch accuary on test data is 83.67%
# 213 epoch accuary on test data is 86.52%
# 214 epoch use 505.00 ms
# 214 epoch loss on test data is 0.48
# 214 epoch accuary on test data is 83.92%
# 214 epoch accuary on test data is 87.02%
# 215 epoch use 508.00 ms
# 215 epoch loss on test data is 0.47
# 215 epoch accuary on test data is 84.46%
# 215 epoch accuary on test data is 86.93%
# 216 epoch use 500.98 ms
# 216 epoch loss on test data is 0.47
# 216 epoch accuary on test data is 83.96%
# 216 epoch accuary on test data is 86.99%
# 217 epoch use 492.96 ms
# 217 epoch loss on test data is 0.47
# 217 epoch accuary on test data is 84.06%
# 217 epoch accuary on test data is 86.86%
# 218 epoch use 518.96 ms
# 218 epoch loss on test data is 0.47
# 218 epoch accuary on test data is 84.19%
# 218 epoch accuary on test data is 87.17%
# 219 epoch use 512.00 ms
# 219 epoch loss on test data is 0.47
# 219 epoch accuary on test data is 84.08%
# 219 epoch accuary on test data is 87.10%
# 220 epoch use 488.00 ms
# 220 epoch loss on test data is 0.47
# 220 epoch accuary on test data is 83.89%
# 220 epoch accuary on test data is 86.90%
# 221 epoch use 506.03 ms
# 221 epoch loss on test data is 0.47
# 221 epoch accuary on test data is 84.06%
# 221 epoch accuary on test data is 86.82%
# 222 epoch use 486.00 ms
# 222 epoch loss on test data is 0.47
# 222 epoch accuary on test data is 84.21%
# 222 epoch accuary on test data is 86.88%
# 223 epoch use 508.00 ms
# 223 epoch loss on test data is 0.47
# 223 epoch accuary on test data is 84.00%
# 223 epoch accuary on test data is 87.38%
# 224 epoch use 517.98 ms
# 224 epoch loss on test data is 0.47
# 224 epoch accuary on test data is 84.14%
# 224 epoch accuary on test data is 86.94%
# 225 epoch use 503.98 ms
# 225 epoch loss on test data is 0.47
# 225 epoch accuary on test data is 84.14%
# 225 epoch accuary on test data is 87.28%
# 226 epoch use 494.01 ms
# 226 epoch loss on test data is 0.47
# 226 epoch accuary on test data is 84.19%
# 226 epoch accuary on test data is 86.81%
# 227 epoch use 510.97 ms
# 227 epoch loss on test data is 0.46
# 227 epoch accuary on test data is 84.21%
# 227 epoch accuary on test data is 87.32%
# 228 epoch use 509.99 ms
# 228 epoch loss on test data is 0.48
# 228 epoch accuary on test data is 83.61%
# 228 epoch accuary on test data is 86.57%
# 229 epoch use 502.00 ms
# 229 epoch loss on test data is 0.47
# 229 epoch accuary on test data is 84.25%
# 229 epoch accuary on test data is 87.71%
# 230 epoch use 500.00 ms
# 230 epoch loss on test data is 0.47
# 230 epoch accuary on test data is 84.53%
# 230 epoch accuary on test data is 87.29%
# 231 epoch use 484.02 ms
# 231 epoch loss on test data is 0.46
# 231 epoch accuary on test data is 84.42%
# 231 epoch accuary on test data is 88.00%
# 232 epoch use 513.03 ms
# 232 epoch loss on test data is 0.47
# 232 epoch accuary on test data is 84.36%
# 232 epoch accuary on test data is 87.66%
# 233 epoch use 497.96 ms
# 233 epoch loss on test data is 0.46
# 233 epoch accuary on test data is 84.35%
# 233 epoch accuary on test data is 87.41%
# 234 epoch use 506.96 ms
# 234 epoch loss on test data is 0.47
# 234 epoch accuary on test data is 84.22%
# 234 epoch accuary on test data is 87.20%
# 235 epoch use 485.00 ms
# 235 epoch loss on test data is 0.47
# 235 epoch accuary on test data is 84.19%
# 235 epoch accuary on test data is 87.67%
# 236 epoch use 492.97 ms
# 236 epoch loss on test data is 0.47
# 236 epoch accuary on test data is 84.29%
# 236 epoch accuary on test data is 87.46%
# 237 epoch use 486.96 ms
# 237 epoch loss on test data is 0.46
# 237 epoch accuary on test data is 84.16%
# 237 epoch accuary on test data is 87.02%
# 238 epoch use 516.00 ms
# 238 epoch loss on test data is 0.47
# 238 epoch accuary on test data is 84.21%
# 238 epoch accuary on test data is 87.30%
# 239 epoch use 505.97 ms
# 239 epoch loss on test data is 0.47
# 239 epoch accuary on test data is 84.50%
# 239 epoch accuary on test data is 87.90%
# 240 epoch use 518.00 ms
# 240 epoch loss on test data is 0.47
# 240 epoch accuary on test data is 84.46%
# 240 epoch accuary on test data is 87.73%
# 241 epoch use 507.01 ms
# 241 epoch loss on test data is 0.47
# 241 epoch accuary on test data is 84.49%
# 241 epoch accuary on test data is 87.60%
# 242 epoch use 504.01 ms
# 242 epoch loss on test data is 0.47
# 242 epoch accuary on test data is 84.24%
# 242 epoch accuary on test data is 87.08%
# 243 epoch use 508.96 ms
# 243 epoch loss on test data is 0.47
# 243 epoch accuary on test data is 84.49%
# 243 epoch accuary on test data is 87.73%
# 244 epoch use 483.99 ms
# 244 epoch loss on test data is 0.48
# 244 epoch accuary on test data is 84.25%
# 244 epoch accuary on test data is 87.15%
# 245 epoch use 511.03 ms
# 245 epoch loss on test data is 0.47
# 245 epoch accuary on test data is 84.42%
# 245 epoch accuary on test data is 87.73%
# 246 epoch use 483.00 ms
# 246 epoch loss on test data is 0.48
# 246 epoch accuary on test data is 84.19%
# 246 epoch accuary on test data is 87.01%
# 247 epoch use 499.97 ms
# 247 epoch loss on test data is 0.47
# 247 epoch accuary on test data is 84.38%
# 247 epoch accuary on test data is 87.70%
# 248 epoch use 495.97 ms
# 248 epoch loss on test data is 0.47
# 248 epoch accuary on test data is 84.42%
# 248 epoch accuary on test data is 87.86%
# 249 epoch use 508.01 ms
# 249 epoch loss on test data is 0.47
# 249 epoch accuary on test data is 84.45%
# 249 epoch accuary on test data is 87.69%
# 250 epoch use 514.01 ms
# 250 epoch loss on test data is 0.46
# 250 epoch accuary on test data is 84.42%
# 250 epoch accuary on test data is 87.99%
# 251 epoch use 512.99 ms
# 251 epoch loss on test data is 0.46
# 251 epoch accuary on test data is 84.39%
# 251 epoch accuary on test data is 87.55%
# 252 epoch use 508.99 ms
# 252 epoch loss on test data is 0.47
# 252 epoch accuary on test data is 84.41%
# 252 epoch accuary on test data is 88.19%
# 253 epoch use 498.00 ms
# 253 epoch loss on test data is 0.47
# 253 epoch accuary on test data is 84.63%
# 253 epoch accuary on test data is 88.11%
# 254 epoch use 506.00 ms
# 254 epoch loss on test data is 0.47
# 254 epoch accuary on test data is 84.17%
# 254 epoch accuary on test data is 87.50%
# 255 epoch use 515.00 ms
# 255 epoch loss on test data is 0.48
# 255 epoch accuary on test data is 84.44%
# 255 epoch accuary on test data is 87.86%
# 256 epoch use 503.97 ms
# 256 epoch loss on test data is 0.47
# 256 epoch accuary on test data is 84.79%
# 256 epoch accuary on test data is 88.42%
# 257 epoch use 518.00 ms
# 257 epoch loss on test data is 0.47
# 257 epoch accuary on test data is 84.26%
# 257 epoch accuary on test data is 87.36%
# 258 epoch use 470.00 ms
# 258 epoch loss on test data is 0.47
# 258 epoch accuary on test data is 84.54%
# 258 epoch accuary on test data is 87.73%
# 259 epoch use 502.94 ms
# 259 epoch loss on test data is 0.48
# 259 epoch accuary on test data is 84.15%
# 259 epoch accuary on test data is 87.52%
# 260 epoch use 509.00 ms
# 260 epoch loss on test data is 0.47
# 260 epoch accuary on test data is 84.46%
# 260 epoch accuary on test data is 87.71%
# 261 epoch use 500.99 ms
# 261 epoch loss on test data is 0.47
# 261 epoch accuary on test data is 84.29%
# 261 epoch accuary on test data is 87.58%
# 262 epoch use 510.96 ms
# 262 epoch loss on test data is 0.46
# 262 epoch accuary on test data is 84.72%
# 262 epoch accuary on test data is 87.96%
# 263 epoch use 495.00 ms
# 263 epoch loss on test data is 0.47
# 263 epoch accuary on test data is 84.58%
# 263 epoch accuary on test data is 88.19%
# 264 epoch use 506.99 ms
# 264 epoch loss on test data is 0.47
# 264 epoch accuary on test data is 84.74%
# 264 epoch accuary on test data is 88.28%
# 265 epoch use 503.02 ms
# 265 epoch loss on test data is 0.48
# 265 epoch accuary on test data is 84.27%
# 265 epoch accuary on test data is 87.75%
# 266 epoch use 520.00 ms
# 266 epoch loss on test data is 0.47
# 266 epoch accuary on test data is 84.72%
# 266 epoch accuary on test data is 88.63%
# 267 epoch use 517.96 ms
# 267 epoch loss on test data is 0.47
# 267 epoch accuary on test data is 84.70%
# 267 epoch accuary on test data is 88.36%
# 268 epoch use 502.00 ms
# 268 epoch loss on test data is 0.47
# 268 epoch accuary on test data is 84.61%
# 268 epoch accuary on test data is 88.45%
# 269 epoch use 508.00 ms
# 269 epoch loss on test data is 0.47
# 269 epoch accuary on test data is 84.62%
# 269 epoch accuary on test data is 88.46%
# 270 epoch use 495.97 ms
# 270 epoch loss on test data is 0.47
# 270 epoch accuary on test data is 84.33%
# 270 epoch accuary on test data is 87.96%
# 271 epoch use 505.00 ms
# 271 epoch loss on test data is 0.47
# 271 epoch accuary on test data is 84.68%
# 271 epoch accuary on test data is 88.44%
# 272 epoch use 511.00 ms
# 272 epoch loss on test data is 0.47
# 272 epoch accuary on test data is 84.74%
# 272 epoch accuary on test data is 88.39%
# 273 epoch use 486.00 ms
# 273 epoch loss on test data is 0.47
# 273 epoch accuary on test data is 84.82%
# 273 epoch accuary on test data is 88.63%
# 274 epoch use 493.97 ms
# 274 epoch loss on test data is 0.47
# 274 epoch accuary on test data is 84.53%
# 274 epoch accuary on test data is 88.09%
# 275 epoch use 515.99 ms
# 275 epoch loss on test data is 0.47
# 275 epoch accuary on test data is 84.73%
# 275 epoch accuary on test data is 88.19%
# 276 epoch use 489.00 ms
# 276 epoch loss on test data is 0.47
# 276 epoch accuary on test data is 84.64%
# 276 epoch accuary on test data is 88.85%
# 277 epoch use 500.99 ms
# 277 epoch loss on test data is 0.46
# 277 epoch accuary on test data is 84.87%
# 277 epoch accuary on test data is 88.80%
# 278 epoch use 513.99 ms
# 278 epoch loss on test data is 0.47
# 278 epoch accuary on test data is 84.61%
# 278 epoch accuary on test data is 88.40%
# 279 epoch use 491.96 ms
# 279 epoch loss on test data is 0.47
# 279 epoch accuary on test data is 84.61%
# 279 epoch accuary on test data is 88.55%
# 280 epoch use 511.00 ms
# 280 epoch loss on test data is 0.47
# 280 epoch accuary on test data is 84.57%
# 280 epoch accuary on test data is 88.48%
# 281 epoch use 510.97 ms
# 281 epoch loss on test data is 0.47
# 281 epoch accuary on test data is 84.59%
# 281 epoch accuary on test data is 88.31%
# 282 epoch use 492.96 ms
# 282 epoch loss on test data is 0.47
# 282 epoch accuary on test data is 84.68%
# 282 epoch accuary on test data is 88.16%
# 283 epoch use 492.96 ms
# 283 epoch loss on test data is 0.48
# 283 epoch accuary on test data is 84.57%
# 283 epoch accuary on test data is 88.44%
# 284 epoch use 488.00 ms
# 284 epoch loss on test data is 0.47
# 284 epoch accuary on test data is 84.29%
# 284 epoch accuary on test data is 88.69%
# 285 epoch use 522.96 ms
# 285 epoch loss on test data is 0.47
# 285 epoch accuary on test data is 84.67%
# 285 epoch accuary on test data is 88.86%
# 286 epoch use 464.00 ms
# 286 epoch loss on test data is 0.49
# 286 epoch accuary on test data is 84.38%
# 286 epoch accuary on test data is 88.26%
# 287 epoch use 501.96 ms
# 287 epoch loss on test data is 0.47
# 287 epoch accuary on test data is 84.81%
# 287 epoch accuary on test data is 88.80%
# 288 epoch use 509.96 ms
# 288 epoch loss on test data is 0.48
# 288 epoch accuary on test data is 84.42%
# 288 epoch accuary on test data is 88.84%
# 289 epoch use 482.02 ms
# 289 epoch loss on test data is 0.47
# 289 epoch accuary on test data is 84.77%
# 289 epoch accuary on test data is 89.04%
# 290 epoch use 490.01 ms
# 290 epoch loss on test data is 0.47
# 290 epoch accuary on test data is 84.76%
# 290 epoch accuary on test data is 88.91%
# 291 epoch use 478.00 ms
# 291 epoch loss on test data is 0.47
# 291 epoch accuary on test data is 84.76%
# 291 epoch accuary on test data is 88.69%
# 292 epoch use 497.96 ms
# 292 epoch loss on test data is 0.47
# 292 epoch accuary on test data is 84.81%
# 292 epoch accuary on test data is 88.80%
# 293 epoch use 495.96 ms
# 293 epoch loss on test data is 0.47
# 293 epoch accuary on test data is 84.49%
# 293 epoch accuary on test data is 88.86%
# 294 epoch use 507.04 ms
# 294 epoch loss on test data is 0.47
# 294 epoch accuary on test data is 84.69%
# 294 epoch accuary on test data is 88.77%
# 295 epoch use 502.97 ms
# 295 epoch loss on test data is 0.47
# 295 epoch accuary on test data is 84.83%
# 295 epoch accuary on test data is 88.91%
# 296 epoch use 519.00 ms
# 296 epoch loss on test data is 0.47
# 296 epoch accuary on test data is 84.71%
# 296 epoch accuary on test data is 89.20%
# 297 epoch use 490.00 ms
# 297 epoch loss on test data is 0.47
# 297 epoch accuary on test data is 84.87%
# 297 epoch accuary on test data is 89.49%
# 298 epoch use 501.96 ms
# 298 epoch loss on test data is 0.46
# 298 epoch accuary on test data is 84.95%
# 298 epoch accuary on test data is 89.00%
# 299 epoch use 508.03 ms
# 299 epoch loss on test data is 0.47
# 299 epoch accuary on test data is 84.56%
# 299 epoch accuary on test data is 88.98%
# 300 epoch use 500.99 ms
# 300 epoch loss on test data is 0.47
# 300 epoch accuary on test data is 84.98%
# 300 epoch accuary on test data is 88.80%
# 301 epoch use 516.96 ms
# 301 epoch loss on test data is 0.47
# 301 epoch accuary on test data is 84.84%
# 301 epoch accuary on test data is 89.40%
# 302 epoch use 500.96 ms
# 302 epoch loss on test data is 0.48
# 302 epoch accuary on test data is 84.78%
# 302 epoch accuary on test data is 88.86%
# 303 epoch use 504.01 ms
# 303 epoch loss on test data is 0.48
# 303 epoch accuary on test data is 84.92%
# 303 epoch accuary on test data is 88.84%
# 304 epoch use 505.97 ms
# 304 epoch loss on test data is 0.47
# 304 epoch accuary on test data is 84.90%
# 304 epoch accuary on test data is 88.73%
# 305 epoch use 485.97 ms
# 305 epoch loss on test data is 0.47
# 305 epoch accuary on test data is 85.04%
# 305 epoch accuary on test data is 89.60%
# 306 epoch use 486.01 ms
# 306 epoch loss on test data is 0.48
# 306 epoch accuary on test data is 84.73%
# 306 epoch accuary on test data is 89.08%
# 307 epoch use 495.00 ms
# 307 epoch loss on test data is 0.48
# 307 epoch accuary on test data is 84.89%
# 307 epoch accuary on test data is 89.14%
# 308 epoch use 481.00 ms
# 308 epoch loss on test data is 0.48
# 308 epoch accuary on test data is 84.92%
# 308 epoch accuary on test data is 89.31%
# 309 epoch use 508.00 ms
# 309 epoch loss on test data is 0.47
# 309 epoch accuary on test data is 84.89%
# 309 epoch accuary on test data is 89.18%
# 310 epoch use 502.96 ms
# 310 epoch loss on test data is 0.47
# 310 epoch accuary on test data is 84.96%
# 310 epoch accuary on test data is 89.11%
# 311 epoch use 504.00 ms
# 311 epoch loss on test data is 0.48
# 311 epoch accuary on test data is 84.98%
# 311 epoch accuary on test data is 89.56%
# 312 epoch use 498.00 ms
# 312 epoch loss on test data is 0.47
# 312 epoch accuary on test data is 84.98%
# 312 epoch accuary on test data is 89.16%
# 313 epoch use 512.97 ms
# 313 epoch loss on test data is 0.48
# 313 epoch accuary on test data is 84.62%
# 313 epoch accuary on test data is 88.66%
# 314 epoch use 492.95 ms
# 314 epoch loss on test data is 0.48
# 314 epoch accuary on test data is 84.86%
# 314 epoch accuary on test data is 89.61%
# 315 epoch use 493.96 ms
# 315 epoch loss on test data is 0.47
# 315 epoch accuary on test data is 85.01%
# 315 epoch accuary on test data is 89.45%
# 316 epoch use 509.97 ms
# 316 epoch loss on test data is 0.48
# 316 epoch accuary on test data is 84.93%
# 316 epoch accuary on test data is 89.63%
# 317 epoch use 496.03 ms
# 317 epoch loss on test data is 0.49
# 317 epoch accuary on test data is 84.58%
# 317 epoch accuary on test data is 88.95%
# 318 epoch use 482.00 ms
# 318 epoch loss on test data is 0.48
# 318 epoch accuary on test data is 84.90%
# 318 epoch accuary on test data is 89.51%
# 319 epoch use 482.97 ms
# 319 epoch loss on test data is 0.47
# 319 epoch accuary on test data is 85.00%
# 319 epoch accuary on test data is 89.59%
# 320 epoch use 501.96 ms
# 320 epoch loss on test data is 0.48
# 320 epoch accuary on test data is 84.65%
# 320 epoch accuary on test data is 88.99%
# 321 epoch use 486.99 ms
# 321 epoch loss on test data is 0.50
# 321 epoch accuary on test data is 84.46%
# 321 epoch accuary on test data is 89.10%
# 322 epoch use 505.04 ms
# 322 epoch loss on test data is 0.48
# 322 epoch accuary on test data is 84.89%
# 322 epoch accuary on test data is 89.08%
# 323 epoch use 514.00 ms
# 323 epoch loss on test data is 0.48
# 323 epoch accuary on test data is 84.85%
# 323 epoch accuary on test data is 89.64%
# 324 epoch use 484.01 ms
# 324 epoch loss on test data is 0.48
# 324 epoch accuary on test data is 84.92%
# 324 epoch accuary on test data is 89.51%
# 325 epoch use 466.00 ms
# 325 epoch loss on test data is 0.48
# 325 epoch accuary on test data is 84.86%
# 325 epoch accuary on test data is 89.46%
# 326 epoch use 518.05 ms
# 326 epoch loss on test data is 0.49
# 326 epoch accuary on test data is 84.72%
# 326 epoch accuary on test data is 89.13%
# 327 epoch use 502.02 ms
# 327 epoch loss on test data is 0.47
# 327 epoch accuary on test data is 84.87%
# 327 epoch accuary on test data is 90.17%
# 328 epoch use 513.98 ms
# 328 epoch loss on test data is 0.49
# 328 epoch accuary on test data is 84.19%
# 328 epoch accuary on test data is 89.24%
# 329 epoch use 508.98 ms
# 329 epoch loss on test data is 0.49
# 329 epoch accuary on test data is 84.45%
# 329 epoch accuary on test data is 89.08%
# 330 epoch use 523.02 ms
# 330 epoch loss on test data is 0.49
# 330 epoch accuary on test data is 84.61%
# 330 epoch accuary on test data is 88.94%
# 331 epoch use 492.99 ms
# 331 epoch loss on test data is 0.49
# 331 epoch accuary on test data is 84.81%
# 331 epoch accuary on test data is 89.65%
# 332 epoch use 483.04 ms
# 332 epoch loss on test data is 0.47
# 332 epoch accuary on test data is 84.97%
# 332 epoch accuary on test data is 89.80%
# 333 epoch use 508.00 ms
# 333 epoch loss on test data is 0.49
# 333 epoch accuary on test data is 84.83%
# 333 epoch accuary on test data is 89.60%
# ...
# 375 epoch use 480.00 ms
# 375 epoch loss on test data is 0.51
# 375 epoch accuary on test data is 84.93%
# 375 epoch accuary on test data is 90.14%
# 376 epoch use 500.04 ms
# 376 epoch loss on test data is 0.50
# 376 epoch accuary on test data is 84.99%
# 376 epoch accuary on test data is 90.77%
# 377 epoch use 492.96 ms
# 377 epoch loss on test data is 0.49
# 377 epoch accuary on test data is 85.09%
# 377 epoch accuary on test data is 90.42%
# 378 epoch use 480.96 ms
# 378 epoch loss on test data is 0.49
# 378 epoch accuary on test data is 84.78%
# 378 epoch accuary on test data is 90.73%
# 379 epoch use 505.96 ms
# 379 epoch loss on test data is 0.49
# 379 epoch accuary on test data is 85.09%
# 379 epoch accuary on test data is 90.71%
# 380 epoch use 510.02 ms
# 380 epoch loss on test data is 0.49
# 380 epoch accuary on test data is 85.15%
# 380 epoch accuary on test data is 90.99%
# 381 epoch use 497.97 ms
# 381 epoch loss on test data is 0.49
# 381 epoch accuary on test data is 85.13%
# 381 epoch accuary on test data is 90.84%
# 382 epoch use 511.00 ms
# 382 epoch loss on test data is 0.50
# 382 epoch accuary on test data is 84.86%
# 382 epoch accuary on test data is 90.20%
# 383 epoch use 494.00 ms
# 383 epoch loss on test data is 0.50
# 383 epoch accuary on test data is 84.74%
# 383 epoch accuary on test data is 90.01%
# 384 epoch use 511.01 ms
# 384 epoch loss on test data is 0.50
# 384 epoch accuary on test data is 85.25%
# 384 epoch accuary on test data is 90.83%
# 385 epoch use 522.96 ms
# 385 epoch loss on test data is 0.50
# 385 epoch accuary on test data is 84.88%
# 385 epoch accuary on test data is 90.36%
# 386 epoch use 500.00 ms
# 386 epoch loss on test data is 0.50
# 386 epoch accuary on test data is 85.20%
# 386 epoch accuary on test data is 91.03%
# 387 epoch use 504.99 ms
# 387 epoch loss on test data is 0.50
# 387 epoch accuary on test data is 85.08%
# 387 epoch accuary on test data is 90.73%
# 388 epoch use 474.00 ms
# 388 epoch loss on test data is 0.49
# 388 epoch accuary on test data is 84.95%
# 388 epoch accuary on test data is 90.92%
# 389 epoch use 484.01 ms
# 389 epoch loss on test data is 0.50
# 389 epoch accuary on test data is 85.14%
# 389 epoch accuary on test data is 90.54%
# 390 epoch use 517.96 ms
# 390 epoch loss on test data is 0.49
# 390 epoch accuary on test data is 85.05%
# 390 epoch accuary on test data is 90.29%
# 391 epoch use 497.00 ms
# 391 epoch loss on test data is 0.50
# 391 epoch accuary on test data is 85.21%
# 391 epoch accuary on test data is 91.05%
# 392 epoch use 492.00 ms
# 392 epoch loss on test data is 0.49
# 392 epoch accuary on test data is 85.33%
# 392 epoch accuary on test data is 90.88%
# 393 epoch use 503.00 ms
# 393 epoch loss on test data is 0.49
# 393 epoch accuary on test data is 85.00%
# 393 epoch accuary on test data is 90.93%
# 394 epoch use 489.97 ms
# 394 epoch loss on test data is 0.49
# 394 epoch accuary on test data is 85.25%
# 394 epoch accuary on test data is 91.03%
# 395 epoch use 479.96 ms
# 395 epoch loss on test data is 0.53
# 395 epoch accuary on test data is 84.14%
# 395 epoch accuary on test data is 89.01%
# 396 epoch use 504.98 ms
# 396 epoch loss on test data is 0.51
# 396 epoch accuary on test data is 85.25%
# 396 epoch accuary on test data is 91.17%
# 397 epoch use 487.00 ms
# 397 epoch loss on test data is 0.50
# 397 epoch accuary on test data is 85.00%
# 397 epoch accuary on test data is 91.08%
# 398 epoch use 502.98 ms
# 398 epoch loss on test data is 0.50
# 398 epoch accuary on test data is 85.33%
# 398 epoch accuary on test data is 90.78%
# 399 epoch use 512.00 ms
# 399 epoch loss on test data is 0.51
# 399 epoch accuary on test data is 84.94%
# 399 epoch accuary on test data is 90.53%
# 400 epoch use 514.96 ms
# 400 epoch loss on test data is 0.50
# 400 epoch accuary on test data is 84.97%
# 400 epoch accuary on test data is 90.64%
# 401 epoch use 491.01 ms
# 401 epoch loss on test data is 0.51
# 401 epoch accuary on test data is 85.43%
# 401 epoch accuary on test data is 91.16%
# 402 epoch use 499.00 ms
# 402 epoch loss on test data is 0.52
# 402 epoch accuary on test data is 85.17%
# 402 epoch accuary on test data is 90.44%
# 403 epoch use 515.01 ms
# 403 epoch loss on test data is 0.50
# 403 epoch accuary on test data is 85.11%
# 403 epoch accuary on test data is 90.78%
# 404 epoch use 459.00 ms
# 404 epoch loss on test data is 0.50
# 404 epoch accuary on test data is 85.24%
# 404 epoch accuary on test data is 90.84%
# 405 epoch use 503.02 ms
# 405 epoch loss on test data is 0.51
# 405 epoch accuary on test data is 84.95%
# 405 epoch accuary on test data is 90.71%
# 406 epoch use 494.00 ms
# 406 epoch loss on test data is 0.51
# 406 epoch accuary on test data is 85.18%
# 406 epoch accuary on test data is 90.65%
# 407 epoch use 495.00 ms
# 407 epoch loss on test data is 0.50
# 407 epoch accuary on test data is 85.25%
# 407 epoch accuary on test data is 90.93%
# 408 epoch use 501.03 ms
# 408 epoch loss on test data is 0.53
# 408 epoch accuary on test data is 84.77%
# 408 epoch accuary on test data is 90.38%
# 409 epoch use 503.00 ms
# 409 epoch loss on test data is 0.51
# 409 epoch accuary on test data is 85.00%
# 409 epoch accuary on test data is 90.81%
# 410 epoch use 487.03 ms
# 410 epoch loss on test data is 0.52
# 410 epoch accuary on test data is 84.91%
# 410 epoch accuary on test data is 90.91%
# 411 epoch use 497.00 ms
# 411 epoch loss on test data is 0.53
# 411 epoch accuary on test data is 84.98%
# 411 epoch accuary on test data is 90.58%
# 412 epoch use 498.00 ms
# 412 epoch loss on test data is 0.50
# 412 epoch accuary on test data is 85.17%
# 412 epoch accuary on test data is 91.52%
# 413 epoch use 496.00 ms
# 413 epoch loss on test data is 0.54
# 413 epoch accuary on test data is 84.35%
# 413 epoch accuary on test data is 89.79%
# 414 epoch use 501.01 ms
# 414 epoch loss on test data is 0.52
# 414 epoch accuary on test data is 85.02%
# 414 epoch accuary on test data is 91.48%
# 415 epoch use 506.00 ms
# 415 epoch loss on test data is 0.50
# 415 epoch accuary on test data is 85.14%
# 415 epoch accuary on test data is 91.08%
# 416 epoch use 497.00 ms
# 416 epoch loss on test data is 0.51
# 416 epoch accuary on test data is 84.80%
# 416 epoch accuary on test data is 90.85%
# 417 epoch use 514.96 ms
# 417 epoch loss on test data is 0.51
# 417 epoch accuary on test data is 85.16%
# 417 epoch accuary on test data is 91.53%
# 418 epoch use 495.98 ms
# 418 epoch loss on test data is 0.51
# 418 epoch accuary on test data is 85.15%
# 418 epoch accuary on test data is 91.29%
# 419 epoch use 494.01 ms
# 419 epoch loss on test data is 0.52
# 419 epoch accuary on test data is 85.13%
# 419 epoch accuary on test data is 91.63%
# 420 epoch use 498.01 ms
# 420 epoch loss on test data is 0.52
# 420 epoch accuary on test data is 85.08%
# 420 epoch accuary on test data is 91.07%
# 421 epoch use 475.01 ms
# 421 epoch loss on test data is 0.50
# 421 epoch accuary on test data is 84.99%
# 421 epoch accuary on test data is 91.43%
# 422 epoch use 477.01 ms
# 422 epoch loss on test data is 0.52
# 422 epoch accuary on test data is 85.08%
# 422 epoch accuary on test data is 91.44%
# 423 epoch use 501.00 ms
# 423 epoch loss on test data is 0.52
# 423 epoch accuary on test data is 84.94%
# 423 epoch accuary on test data is 91.34%
# 424 epoch use 474.97 ms
# 424 epoch loss on test data is 0.52
# 424 epoch accuary on test data is 85.01%
# 424 epoch accuary on test data is 91.29%
# 425 epoch use 480.96 ms
# 425 epoch loss on test data is 0.54
# 425 epoch accuary on test data is 84.88%
# 425 epoch accuary on test data is 90.66%
# 426 epoch use 515.96 ms
# 426 epoch loss on test data is 0.52
# 426 epoch accuary on test data is 85.32%
# 426 epoch accuary on test data is 91.18%
# 427 epoch use 500.97 ms
# 427 epoch loss on test data is 0.51
# 427 epoch accuary on test data is 85.37%
# 427 epoch accuary on test data is 91.68%
# 428 epoch use 503.00 ms
# 428 epoch loss on test data is 0.52
# 428 epoch accuary on test data is 84.93%
# 428 epoch accuary on test data is 91.17%
# 429 epoch use 493.00 ms
# 429 epoch loss on test data is 0.52
# 429 epoch accuary on test data is 85.14%
# 429 epoch accuary on test data is 91.66%
# 430 epoch use 480.00 ms
# 430 epoch loss on test data is 0.51
# 430 epoch accuary on test data is 85.04%
# 430 epoch accuary on test data is 91.49%
# 431 epoch use 505.96 ms
# 431 epoch loss on test data is 0.52
# 431 epoch accuary on test data is 85.43%
# 431 epoch accuary on test data is 91.64%
# 432 epoch use 520.97 ms
# 432 epoch loss on test data is 0.53
# 432 epoch accuary on test data is 85.05%
# 432 epoch accuary on test data is 90.86%
# 433 epoch use 508.96 ms
# 433 epoch loss on test data is 0.52
# 433 epoch accuary on test data is 85.01%
# 433 epoch accuary on test data is 91.56%
# 434 epoch use 506.00 ms
# 434 epoch loss on test data is 0.52
# 434 epoch accuary on test data is 84.92%
# 434 epoch accuary on test data is 90.96%
# 435 epoch use 500.00 ms
# 435 epoch loss on test data is 0.51
# 435 epoch accuary on test data is 85.15%
# 435 epoch accuary on test data is 91.79%
# 436 epoch use 515.01 ms
# 436 epoch loss on test data is 0.53
# 436 epoch accuary on test data is 85.43%
# 436 epoch accuary on test data is 91.25%
# 437 epoch use 499.00 ms
# 437 epoch loss on test data is 0.52
# 437 epoch accuary on test data is 85.05%
# 437 epoch accuary on test data is 91.65%
# 438 epoch use 497.00 ms
# 438 epoch loss on test data is 0.52
# 438 epoch accuary on test data is 85.22%
# 438 epoch accuary on test data is 91.76%
# 439 epoch use 479.97 ms
# 439 epoch loss on test data is 0.53
# 439 epoch accuary on test data is 84.55%
# 439 epoch accuary on test data is 91.38%
# 440 epoch use 493.01 ms
# 440 epoch loss on test data is 0.52
# 440 epoch accuary on test data is 85.36%
# 440 epoch accuary on test data is 91.32%
# 441 epoch use 505.96 ms
# 441 epoch loss on test data is 0.52
# 441 epoch accuary on test data is 85.03%
# 441 epoch accuary on test data is 91.22%
# 442 epoch use 515.96 ms
# 442 epoch loss on test data is 0.53
# 442 epoch accuary on test data is 85.02%
# 442 epoch accuary on test data is 91.53%
# 443 epoch use 516.00 ms
# 443 epoch loss on test data is 0.53
# 443 epoch accuary on test data is 85.53%
# 443 epoch accuary on test data is 91.81%
# 444 epoch use 505.97 ms
# 444 epoch loss on test data is 0.52
# 444 epoch accuary on test data is 84.94%
# 444 epoch accuary on test data is 91.36%
# 445 epoch use 507.97 ms
# 445 epoch loss on test data is 0.53
# 445 epoch accuary on test data is 85.29%
# 445 epoch accuary on test data is 91.31%
# 446 epoch use 514.99 ms
# 446 epoch loss on test data is 0.53
# 446 epoch accuary on test data is 85.13%
# 446 epoch accuary on test data is 91.49%
# 447 epoch use 505.97 ms
# 447 epoch loss on test data is 0.53
# 447 epoch accuary on test data is 85.22%
# 447 epoch accuary on test data is 91.82%
# 448 epoch use 482.00 ms
# 448 epoch loss on test data is 0.53
# 448 epoch accuary on test data is 85.05%
# 448 epoch accuary on test data is 91.74%
# 449 epoch use 510.05 ms
# 449 epoch loss on test data is 0.53
# 449 epoch accuary on test data is 85.23%
# 449 epoch accuary on test data is 91.56%
# 450 epoch use 489.97 ms
# 450 epoch loss on test data is 0.53
# 450 epoch accuary on test data is 85.33%
# 450 epoch accuary on test data is 91.67%
# 451 epoch use 491.96 ms
# 451 epoch loss on test data is 0.53
# 451 epoch accuary on test data is 85.20%
# 451 epoch accuary on test data is 91.51%
# 452 epoch use 484.96 ms
# 452 epoch loss on test data is 0.53
# 452 epoch accuary on test data is 84.86%
# 452 epoch accuary on test data is 91.43%
# 453 epoch use 502.00 ms
# 453 epoch loss on test data is 0.55
# 453 epoch accuary on test data is 85.29%
# 453 epoch accuary on test data is 91.71%
# 454 epoch use 497.00 ms
# 454 epoch loss on test data is 0.53
# 454 epoch accuary on test data is 84.97%
# 454 epoch accuary on test data is 91.81%
# 455 epoch use 500.00 ms
# 455 epoch loss on test data is 0.52
# 455 epoch accuary on test data is 85.12%
# 455 epoch accuary on test data is 91.69%
# 456 epoch use 503.01 ms
# 456 epoch loss on test data is 0.55
# 456 epoch accuary on test data is 84.98%
# 456 epoch accuary on test data is 91.43%
# 457 epoch use 486.96 ms
# 457 epoch loss on test data is 0.53
# 457 epoch accuary on test data is 85.41%
# 457 epoch accuary on test data is 91.63%
# 458 epoch use 506.96 ms
# 458 epoch loss on test data is 0.54
# 458 epoch accuary on test data is 85.17%
# 458 epoch accuary on test data is 91.58%
# 459 epoch use 518.01 ms
# 459 epoch loss on test data is 0.53
# 459 epoch accuary on test data is 85.22%
# 459 epoch accuary on test data is 91.78%
# 460 epoch use 507.01 ms
# 460 epoch loss on test data is 0.55
# 460 epoch accuary on test data is 85.16%
# 460 epoch accuary on test data is 91.74%
# 461 epoch use 486.00 ms
# 461 epoch loss on test data is 0.52
# 461 epoch accuary on test data is 85.18%
# 461 epoch accuary on test data is 91.83%
# 462 epoch use 488.96 ms
# 462 epoch loss on test data is 0.53
# 462 epoch accuary on test data is 85.16%
# 462 epoch accuary on test data is 91.70%
# 463 epoch use 507.00 ms
# 463 epoch loss on test data is 0.53
# 463 epoch accuary on test data is 85.11%
# 463 epoch accuary on test data is 91.47%
# 464 epoch use 515.98 ms
# 464 epoch loss on test data is 0.54
# 464 epoch accuary on test data is 85.25%
# 464 epoch accuary on test data is 91.83%
# 465 epoch use 486.99 ms
# 465 epoch loss on test data is 0.52
# 465 epoch accuary on test data is 85.27%
# 465 epoch accuary on test data is 92.06%
# 466 epoch use 498.96 ms
# 466 epoch loss on test data is 0.54
# 466 epoch accuary on test data is 85.41%
# 466 epoch accuary on test data is 92.13%
# 467 epoch use 480.96 ms
# 467 epoch loss on test data is 0.52
# 467 epoch accuary on test data is 85.34%
# 467 epoch accuary on test data is 92.06%
# 468 epoch use 491.99 ms
# 468 epoch loss on test data is 0.55
# 468 epoch accuary on test data is 85.21%
# 468 epoch accuary on test data is 91.50%
# 469 epoch use 510.98 ms
# 469 epoch loss on test data is 0.53
# 469 epoch accuary on test data is 84.86%
# 469 epoch accuary on test data is 91.75%
# 470 epoch use 500.00 ms
# 470 epoch loss on test data is 0.54
# 470 epoch accuary on test data is 85.23%
# 470 epoch accuary on test data is 92.10%
# 471 epoch use 498.97 ms
# 471 epoch loss on test data is 0.54
# 471 epoch accuary on test data is 85.03%
# 471 epoch accuary on test data is 92.18%
# 472 epoch use 549.01 ms
# 472 epoch loss on test data is 0.54
# 472 epoch accuary on test data is 85.31%
# 472 epoch accuary on test data is 91.60%
# 473 epoch use 531.99 ms
# 473 epoch loss on test data is 0.53
# 473 epoch accuary on test data is 85.17%
# 473 epoch accuary on test data is 92.19%
# 474 epoch use 529.00 ms
# 474 epoch loss on test data is 0.54
# 474 epoch accuary on test data is 85.19%
# 474 epoch accuary on test data is 92.35%
# 475 epoch use 596.00 ms
# 475 epoch loss on test data is 0.55
# 475 epoch accuary on test data is 85.11%
# 475 epoch accuary on test data is 92.20%
# 476 epoch use 510.00 ms
# 476 epoch loss on test data is 0.54
# 476 epoch accuary on test data is 84.96%
# 476 epoch accuary on test data is 92.02%
# 477 epoch use 521.99 ms
# 477 epoch loss on test data is 0.55
# 477 epoch accuary on test data is 84.97%
# 477 epoch accuary on test data is 91.90%
# 478 epoch use 536.00 ms
# 478 epoch loss on test data is 0.55
# 478 epoch accuary on test data is 85.21%
# 478 epoch accuary on test data is 92.22%
# 479 epoch use 500.96 ms
# 479 epoch loss on test data is 0.54
# 479 epoch accuary on test data is 85.41%
# 479 epoch accuary on test data is 92.36%
# 480 epoch use 518.01 ms
# 480 epoch loss on test data is 0.53
# 480 epoch accuary on test data is 85.15%
# 480 epoch accuary on test data is 92.60%
# 481 epoch use 564.97 ms
# 481 epoch loss on test data is 0.54
# 481 epoch accuary on test data is 85.26%
# 481 epoch accuary on test data is 92.13%
# 482 epoch use 487.96 ms
# 482 epoch loss on test data is 0.54
# 482 epoch accuary on test data is 84.99%
# 482 epoch accuary on test data is 91.32%
# 483 epoch use 522.00 ms
# 483 epoch loss on test data is 0.53
# 483 epoch accuary on test data is 85.20%
# 483 epoch accuary on test data is 91.84%
# 484 epoch use 565.96 ms
# 484 epoch loss on test data is 0.54
# 484 epoch accuary on test data is 85.32%
# 484 epoch accuary on test data is 92.19%
# 485 epoch use 577.99 ms
